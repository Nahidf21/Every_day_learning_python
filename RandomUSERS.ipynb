# %%
# !pip install randomuser
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5067 sha256=a485d50c087708600e0d4460e24ec75a27645a2c8f6951a8f490af055ba402e0
#   Stored in directory: /Users/nahidferdous/Library/Caches/pip/wheels/41/6f/23/878c103a235dc2d4e85a3965c124aae8a28470c541b81aa2ba
# Successfully built randomuser
# ...

# %%
from randomuser import RandomUser
import pandas as pd

# %%
# first we create a random user object r
r=RandomUser()

# %%
some_list=r.generate_users(10)
some_list

# %%
name=r.get_full_name()
name
# Out:
# 'James Smith'

# %%
for user in some_list:
    print(user.get_full_name()," ",user.get_email())
# Out:
# Ryan Tucker   ryan.tucker@example.com
# Koray Erberk   koray.erberk@example.com
# Morris Lopez   morris.lopez@example.com
# Isabella Rasmussen   isabella.rasmussen@example.com
# Sandro Moreau   sandro.moreau@example.com
# محمدامين موسوی   mhmdmyn.mwswy@example.com
# David Smith   david.smith@example.com
# Teodomiro Silveira   teodomiro.silveira@example.com
# Juliet Van Ravenzwaaij   juliet.vanravenzwaaij@example.com
# Ed Roersma   ed.roersma@example.com

# %%
#In this Exercise, generate photos of the random 5 users.

# %%
from randomuser import RandomUser 
import pandas as pd

# %%
r=RandomUser()

# %%
new_list=r.generate_users(5)
new_list

# %%
for user in new_list:
    print(user.get_first_name()," ", user.get_picture()," ",user.get_age())
# Out:
# Lilja   https://randomuser.me/api/portraits/women/60.jpg   36
# Hazel   https://randomuser.me/api/portraits/women/52.jpg   42
# آدرین   https://randomuser.me/api/portraits/men/37.jpg   45
# Martino   https://randomuser.me/api/portraits/men/97.jpg   29
# Emma   https://randomuser.me/api/portraits/women/95.jpg   62

# %%
def get_user():
    users=[]
    
    for user in RandomUser.generate_users(10):
        users.append({"Name": user.get_username(), "Gender": user.get_gender(), "City":user.get_city(), "Photo": user.get_picture()})
        
    return users

# %%
get_user()
# Out:
# [{'Name': 'sadelephant501',
#   'Gender': 'male',
#   'City': 'Queimados',
#   'Photo': 'https://randomuser.me/api/portraits/men/14.jpg'},
#  {'Name': 'happysnake602',
#   'Gender': 'female',
#   'City': 'Port Macquarie',
#   'Photo': 'https://randomuser.me/api/portraits/women/90.jpg'},
#  {'Name': 'tinygoose603',
#   'Gender': 'male',
#   'City': 'Nîmes',
#   'Photo': 'https://randomuser.me/api/portraits/men/56.jpg'},
#  {'Name': 'brownmouse255',
#   'Gender': 'female',
#   'City': 'Bray',
#   'Photo': 'https://randomuser.me/api/portraits/women/33.jpg'},
#  {'Name': 'blackcat546',
#   'Gender': 'male',
#   'City': 'Sunderland',
#   'Photo': 'https://randomuser.me/api/portraits/men/36.jpg'},
#  {'Name': 'blueswan664',
#   'Gender': 'male',
#   'City': 'Trabzon',
#   'Photo': 'https://randomuser.me/api/portraits/men/97.jpg'},
#  {'Name': 'organicsnake303',
#   'Gender': 'male',
#   'City': 'Hamilton',
#   'Photo': 'https://randomuser.me/api/portraits/men/74.jpg'},
# ...

# %%
df1 = pd.DataFrame(get_user())
df1
# Out:
#               Name  Gender                  City  \
# 0      crazydog297  female               Geelong
# 1    organicdog580    male               Lotzwil
# 2   orangekoala522  female  Heilig Landstichting
# 3      greendog324  female              Vipperød
# 4     lazytiger192  female             St Davids
# 5        reddog808  female              Hereford
# 6       redswan700    male           South River
# 7  organickoala874    male               Clinton
# 8    brownzebra749  female                  Naas
# 9     blackbird370    male            Gloucester
#
#                                               Photo
# 0  https://randomuser.me/api/portraits/women/21.jpg
# 1     https://randomuser.me/api/portraits/men/8.jpg
# 2  https://randomuser.me/api/portraits/women/25.jpg
# 3  https://randomuser.me/api/portraits/women/89.jpg
# 4  https://randomuser.me/api/portraits/women/21.jpg
# 5  https://randomuser.me/api/portraits/women/47.jpg
# 6    https://randomuser.me/api/portraits/men/38.jpg
# ...

# %% [markdown]
# ##Example 2: Fruitvice API

# %%
import requests as req

# %%
import json

# %%
data= req.get("https://fruityvice.com/api/fruit/all")
data
# Out:
# <Response [200]>

# %%
results=json.loads(data.text)

# %%
df=pd.DataFrame(results)

# %%
df.head()
# Out:
#          name  id      family         order      genus  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria
# 2      Banana   1    Musaceae  Zingiberales       Musa
# 3      Tomato   5  Solanaceae     Solanales    Solanum
# 4        Pear   4    Rosaceae       Rosales      Pyrus
#
#                                           nutritions
# 0  {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2  {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3  {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4  {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...

# %%
df2=pd.json_normalize(results)

# %%
df2
# Out:
#             name  id           family             order         genus  \
# 0      Persimmon  52        Ebenaceae           Rosales     Diospyros
# 1     Strawberry   3         Rosaceae           Rosales      Fragaria
# 2         Banana   1         Musaceae      Zingiberales          Musa
# 3         Tomato   5       Solanaceae         Solanales       Solanum
# 4           Pear   4         Rosaceae           Rosales         Pyrus
# 5         Durian  60        Malvaceae          Malvales         Durio
# 6     Blackberry  64         Rosaceae           Rosales         Rubus
# 7    Lingonberry  65        Ericaceae          Ericales     Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes       Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales        Litchi
# 10     Pineapple  10     Bromeliaceae            Poales        Ananas
# 11           Fig  68         Moraceae           Rosales         Ficus
# ...

# %%
cherry=df2.loc[df2['name']=="Cherry"]
(cherry.iloc[0]["family"]),(cherry.iloc[0]["genus"])
# Out:
# ('Rosaceae', 'Prunus')

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %%
ch1= df2.loc[df2["name"]=="Cherry"]
ch1
# Out:
#       name  id    family    order   genus  nutritions.calories  \
# 38  Cherry   9  Rosaceae  Rosales  Prunus                   50
#
#     nutritions.fat  nutritions.sugar  nutritions.carbohydrates  \
# 38             0.3               8.0                      12.0
#
#     nutritions.protein
# 38                 1.0

# %%
ch1.loc[38,"family"], ch1.loc[38,"genus"],
# Out:
# ('Rosaceae', 'Prunus')
